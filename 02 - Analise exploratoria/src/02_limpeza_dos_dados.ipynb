# %%
import sys 
import os 

sys.path.append(os.path.abspath(".."))

# %%
import pandas as pd 
import numpy as np
import unicodedata
import re
from pathlib import Path

from config.data_cleaning_config import (
    DEFAULT_DROP_COLUMNS,
    COLUNAS_TEXTO,
    COLUNAS_BINARIAS,
    COLUNA_DIA_SEMANA,
    COLUNA_MES,
    COLUNA_HORA,
    COLUNA_BAIRRO,
    COLUNA_NATUREZA_DESCRICAO1,
    COLUNA_NATUREZA_DESCRICAO2,
    COLUNA_NATUREZA_DESCRICAO3,
    COLUNA_NATUREZA_DESCRICAO4,
    COLUNA_NATUREZA_DESCRICAO5,
)

from config.bairro_cleaning_config import (
    VALORES_INVALIDOS_BAIRRO,
    REGIAO_METROPOLITANA,
    MAPA_BAIRRO
)

# %%
data_dir = Path("../data/base_de_dados")
arquivo = data_dir / "base_unificada.csv"

# %%
output_dir = Path("../data/cleaned")
output_dir.mkdir(parents=True, exist_ok=True)

arquivo_limpo = output_dir / "base_unificada.csv"

# %%
df = pd.read_csv(arquivo, sep=";", encoding="latin1", dtype=str)

# %% [markdown]
# ## 01. Padronização dos dados de texto
#
# Precisamos de uma função que faça a limpeza dos campos de texto da base de dados com o objetivo de padronizar os valores. Por exemplo, 'Centro Cívico' e 'centro civico' devem ser tratados como iguais. Para isso, iremos remover a acentuação, converter tudo para letras minúsculas e eliminar caracteres especiais, mantendo apenas letras, números e espaços.

# %%
def limpar_texto(valor):
    if pd.isna(valor):
        return pd.NA
    
    valor = str(valor).strip().lower()
    
    valor = unicodedata.normalize("NFKD", valor)
    valor = valor.encode("ascii", "ignore").decode("utf-8")
    
    valor = re.sub(r"[^a-z0-9\s]", " ", valor)
    valor = re.sub(r"\s+", " ", valor).strip()
    
    return valor if valor else pd.NA

# %% [markdown]
# Essa função irá executar:
#
# 1. Tratamento de valores nlos: se o valor for NaN, a função retorna `pd.NA`
# 2. Conversão para string e limpeza básica: o valor é convertido para string, removeremos espaços extras no início e no fim (`.strip()`) e transformamos tudo em letras minúsculas (.lower())
# 3. Remoção de acentos: usamos `unicodedata.normalize("NFKD", valor)` para decompor os caracteres acentuados (ex: "ção" vira "c~a~o"), e depois `.encode("ascii", "ignore")` elimina os acentos, mantendo apenas os caracteres ASCII básicos.
# 4. Filtragem de caracteres: com `re.sub(r"[^a-z0-9\s]", " ", valor)`, substituímos qualquer caractere que não seja letra minúscula, número ou espaço por um espaço em branco. Isso remove pontuação, símbolos e outros caracteres especiais. Esse espaço em branco é normalizado com `re.sub(r"\s+", " ", valor).strip()`, onde é substituida sequência de espaços por um único espaço e `.strip()` remove os espaços desnecessários das bordas.
#
# Ao fim, se toda a limpeza retornar uma string vazia, retornamos pd.NA. Caso contrário, retornamos o texto limpo.

# %% [markdown]
# ## 02. Padronização de colunas binárias
#
# Para padronizar colunas binárias, definindo `0` como `False` e `1` como `True`, é necessário primeiro identificar todos os valores distintos presentes na base de dados. Isso garante que o mapeamento seja feito corretamente. Para identificar todos os valores únicos na tupla `COLUNAS_BINARIAS`, disponibilizado em `config/data_cleaning_config.py`, faremos:

# %%
valores_unicos = {col: set() for col in COLUNAS_BINARIAS}

# %%
for col in COLUNAS_BINARIAS:
    if col in df.columns:
        valores = df[col].dropna().unique()
        valores_unicos[col].update(valores)

for col, valores in valores_unicos.items():
    print(f"\n{col}:")
    for valor in sorted(valores):
        print(valor)
# Out:
# FLAG_EQUIPAMENTO_URBANO:
# NÃO
# SIM
# f
# t
#
# FLAG_FLAGRANTE:
# NÃO
# NÃO
# SIM
#
# NATUREZA1_DEFESA_CIVIL:
# 0
# 1
#
# NATUREZA2_DEFESA_CIVIL:
# 0
# 1
#
# NATUREZA3_DEFESA_CIVIL:
# 0
# 1
#
# NATUREZA4_DEFESA_CIVIL:
# 0
# 1
#
# NATUREZA5_DEFESA_CIVIL:
# 0

# %%
def mapear_binario(valor):

    if pd.isna(valor):
        return 0
    
    s = str(valor).strip().lower()

    if s in ('1.0', '0.0'):
        return 1 if s == '1.0' else 0

    valor_limpo = limpar_texto(valor)

    if pd.isna(valor_limpo):
        return 0

    if valor_limpo in ('sim', 'y', 't', '1'):
        return  1
    
    if valor_limpo in ('n', 'nao', 'f', '0', '-----------------------',
                        '--------------', '----------------------',
                        '----------------------', '----------------------', 
                        '----------------------', '----------------------'):
        return 0
    
    return 0

# %% [markdown]
# ## 03. Mapeamento dos dias da semana
#
# Assim como foi feito para as colunas binárias, iremos encontrar os valores únicos para a coluna `OCORRENCIA_DIA_SEMANA` e fazer o mapeamento para transformar em inteiro.

# %%
valores_unicos = {col: set() for col in COLUNA_DIA_SEMANA}

# %%
for col in COLUNA_DIA_SEMANA:
    if col in df.columns:
        valores = df[col].dropna().unique()
        valores_unicos[col].update(valores)

for col, valores in valores_unicos.items():
    print(f"\n{col}:")
    for valor in sorted(valores):
        print(valor)
# Out:
# OCORRENCIA_DIA_SEMANA:
# DOMINGO
# Domingo
# QUARTA
# QUINTA
# Quarta
# Quinta
# SEGUNDA
# SEXTA
# Segunda
# Sexta
# SÁBADO
# SÃ¡bado
# TERÇA
# TerÃ§a

# %%
def mapear_dia_semana(valor):

    if pd.isna(valor):
        return 0
    
    texto_limpo = limpar_texto(valor)

    if pd.isna(texto_limpo) or texto_limpo == '':
        return 0
    
    mapa_dias = {
        'domingo': 1,
        'segunda': 2,
        'terca': 3,
        'quarta': 4,
        'quinta': 5,
        'sexta': 6,
        'sabado': 7
    }

    return mapa_dias.get(texto_limpo, 0)

# %% [markdown]
# ## 04. Tratamento da coluna OCORRENCIA_HORA
#
# Iremos padronizar a coluna OCORRENCIA_HORA que possui os registros no formato HH:MM:SS (hora, minuto e segundo) e, a partir dela, criar as colunas adicionais hora e minuto, descartando os segundos.

# %%
def tratar_coluna_hora(df, coluna):

    if coluna not in df.columns:
        return df 
    
    serie_hora = pd.to_datetime(df[coluna], format="%H:%M:%S", errors="coerce")

    df[coluna] = serie_hora.dt.strftime("%H:%M:%S")

    df[f"{coluna}_HORA"] = serie_hora.dt.hour.astype("Int64")
    df[f"{coluna}_MINUTO"] = serie_hora.dt.minute.astype("Int64")

    df.drop(columns=[coluna], inplace=True)
    
    return df

# %% [markdown]
# ## 05. Flags: MANHA, TARDE, NOITE, MADRUGADA
#
# Vamos criar quatro colunas binária, indicando em qual período do dia a hora de uma ocorrência se enquadrada: madrugada, manhã, tarde ou noite. Cada coluna recebe o valor `1` (verdadeiro) ou `0` (falso). Para isso, utilizaremos os intervalos:
#
# - Madrugada: 00:00 - 05:59
# - Manhã: 06:00 - 11:59
# - Tarde: 12:00 - 17:59
# - Noite: 18:00 - 23:59

# %%
def adicionar_periodo_dia(df, coluna_hora):

    if coluna_hora not in df.columns:
        return df 
    
    horas = pd.to_numeric(df[coluna_hora], errors="coerce")

    df["MADRUGADA"] = ((horas >= 0) & (horas <= 5)).astype("Int64")
    df["MANHA"] = ((horas >= 6) & (horas <= 11)).astype("Int64")
    df["TARDE"] = ((horas >= 12) & (horas <= 17)).astype("Int64")
    df["NOITE"] = ((horas >= 18) & (horas <= 23)).astype("Int64")

    return df

# %% [markdown]
# ## 06. Erros de digitação e padronizações
#
# Precisaremos investigar erros de digitação, abreviações e similaridades nas seguintes colunas:
#
# - `ATENDIMENTO_BAIRRO_NOME`;
# - `NATUREZA1_DESCRICAO`;
# - `NATUREZA2_DESCRICAO`;
# - `NATUREZA3_DESCRICAO`;
# - `NATUREZA4_DESCRICAO`;
# - `NATUREZA5_DESCRICAO`;
#
# O tratamento consistirá em analisar os valores únicos de cada coluna e desenvolver scripts específicos para cada caso.

# %% [markdown]
# #### `ATENDIMENTO_BAIRRO_NOME`

# %% [markdown]
# Vamos investigar valores únicos no cadastro dos nomes dos bairros:

# %%
valores_unicos = {col: set() for col in COLUNA_BAIRRO}

for col in COLUNA_BAIRRO:
    if col in df:
        valores = df[col].apply(limpar_texto).dropna().unique()
        valores_unicos[col].update(valores)

for col, valores in valores_unicos.items():
    print(f"\n{col}:")
    for valor in sorted(valores):
        print(valor)
# Out:
# ATENDIMENTO_BAIRRO_NOME:
# abranches
# afonso pena
# agua verde
# aguas belas
# ahao
# ahu
# alto boqueirao
# alto da gla3ria
# alto da gloria
# alto da rua xv
# atuba
# augusta
# bacacheri
# bairro alto
# bairro ficticio
# bairro nao informado
# bairro nao localizad
# bairro oliveira
# barigua
# barigui
# barreirinha
# barro preto
# batel
# belas aguas
# bigorrilho
# boa vista
# bom retiro
# boqueirao
# borda do campo
# braga
# butiatuvinha
# cabral
# cachoeira
# cajuru
# campina do siqueira
# campinha grande do s
# campo comprido
# campo de santana
# campo de sao benedit
# campo largo
# campo pequeno
# canguiri
# capanema
# capao da imbuia
# capao raso
# casa
# cascatinha
# caximba
# centro
# centro cavico
# centro civico
# champagnat
# cic
# cidade industrial
# cidade industrial de
# cidade jardim
# colombo
# colonia faria
# colonia sao venancio
# cristo rei
# ecoville
# estados
# estancia pinhais
# eucaliptos
# fanny
# fazendinha
# ferraria
# formoso
# francisco gorski
# ganchinho
# gralha azul
# guaara
# guabirotuba
# guaira
# guatupe
# hauer
# higiena3polis
# hugo lange
# iguacu 01
# iguacu 1
# indicacoes cancelada
# ipe 2
# jardim bela vista
# jardim boa vista
# jardim bom pastor
# jardim botanico
# jardim colonial
# jardim das amaricas
# jardim das americas
# jardim industrial
# jardim loanda
# jardim osasco
# jardim pedro demete
# jardim primavera
# jardim rafaela
# jardim santa monica
# jardim schaffer
# jardim social
# jardim weissopolis
# jd dona belizaria
# jd europa
# jd ipe
# jd orestes tha
# jd suissa
# jr taisa
# juvevaa
# juveve
# lamenha grande
# lamenha pequena
# linda3ia
# lindoia
# lot marinoni
# loteamento sao geron
# maracana
# maria antonieta
# maua
# menino deus
# mercaas
# merces
# monte rey
# mossunguaa
# mossungue
# nacoes
# nao encontrado
# nao informado
# nf
# ni
# novo mundo
# orleans
# osasco
# ouro fino
# paes leme
# palmeirinha
# parolin
# parque da fonte
# parque das fontes
# parque das nascentes
# passaaona
# pca espanha
# pilarzinho
# pineville
# pinhais
# pinheirinho
# piraquara
# planta deodoro
# planta meireles
# portao
# prado velho
# quatro barras
# rainha
# rebouaas
# reboucas
# rio verde
# riviera
# roca grande
# roca negra
# santa candida
# santa felicidade
# santa luzia
# santa monica
# santa quitaria
# santa quiteria
# santa teresinha
# santa terezinha
# santo antonio
# santo inacio
# sao benedito
# sao braz
# sao cristovao
# sao francisco
# sao geronimo
# sao joao
# sao jorge
# sao jose
# sao jose dos pinhais
# sao judas tadeu
# sao lourenao
# sao lourenco
# sao miguel
# sao pedro
# sao sebastiao
# sao thomas
# sao thomaz
# satio cercado
# sem dados
# seminario
# sit cercado
# sitio cercado
# sitio das palmeiras
# taboao
# tamandare
# tangua
# taruma
# tatuquara
# thomas coelho
# thomaz coelho
# tindiquera
# tingui
# uberaba
# umbara
# veneza
# vila bancaria
# vila formosa
# vila graziela
# vila ipanema
# vila izabel
# vila maria antonieta
# vila perneta
# vista alegre
# xaxim

# %% [markdown]
# Há diversos casos de erros de digitação, similaridades nos dados e exemplos que precisam ser excluidos, por exemplo:
#
# - `centro cavico` (erro de digitação para `centro civico`);
# - `alto da gla3ria` (erro de digitação para `alto da gloria`)
# - `cic` (abreviação de `cidade industrial`);
# - `bairro ficticio` (dado que precisa ser excluído).
#
# Para evitar perda de informação e facilitar a análise, criaremos um mapeamento na pasta config. Esse mapa será responsável por aplicar os ajutes necessários e padronizar todos os valores de entrada existentes.

# %% [markdown]
# Na pasta `config`, foi criado o arquivo `bairro_cleaning_config.py`, que contém três mapas:
#
# - `VALORES_INVALIDOS_BAIRRO`;
# - `REGIAO_METROPOLITANA`;
# - `MAPA_BAIRRO`.
#
# O primeiro mapa armazena valores de entrada que serão descartados por não fornecerem informação precisa sobre a localização, o que prejudicaria a análise dos dados. O segundo também será descartado, pois se refere à região metropolitana de Curitiba e não ao município em si. Já o terceiro contém correções para erros de digitação em nomes de bairros que pertencem a Curitiba.

# %%
COLUNA_BAIRRO_NOME = COLUNA_BAIRRO[0]
BAIRROS_DESCARTAR = VALORES_INVALIDOS_BAIRRO | REGIAO_METROPOLITANA

# %%
def padronizar_bairro(valor):
    bairro = limpar_texto(valor)

    if pd.isna(bairro):
        return pd.NA 
    
    if bairro in BAIRROS_DESCARTAR:
        return pd.NA 
    
    return MAPA_BAIRRO.get(bairro, bairro)

# %% [markdown]
# #### `NATUREZA_DESCRICAO`

# %% [markdown]
# Vamos investigar valores únicos no cadastro de NATUREZA1_DESCRICAO:

# %%
valores_unicos = {col: set() for col in COLUNA_NATUREZA_DESCRICAO1}

for col in COLUNA_NATUREZA_DESCRICAO1:
    if col in df:
        valores = df[col].apply(limpar_texto).dropna().unique()
        valores_unicos[col].update(valores)

for col, valores in valores_unicos.items():
    print(f"\n{col}:")
    for valor in sorted(valores):
        print(valor)
# Out:
# NATUREZA1_DESCRICAO:
# abalo sismico
# abandono de funcao
# abandono de incapaz
# abito
# abuso de incapazes
# achado
# acidente de transito
# acidente viatura
# afogamento
# afundamento de piso
# agressao fasica verbal
# agressao fisica verbal
# aifu
# alagamento
# alarmes
# aliciamento de menor
# ameaaa
# ameaca
# animais
# antecedentes criminais verificacao
# apoio
# apologia de crime ou criminoso
# apreensao de materiais
# apropriaaao indabita
# apropriacao indebita
# argaos acionados
# arrastao
# ataque cao feroz
# ataque de insetos
# atentado violento ao pudor
# aterro irregular
# atitude suspeita
# atos obscenos libidinosos
# avaria em equipamento patrima nio nao intencional
# avaria em equipamento patrimonio nao intencional
# averiguaaao comarcio ilegal
# averiguaaao cosedi
# averiguaaao defesa civil
# averiguacao
# averiguacao cosedi
# averiguacao defesa civil
# banho em local impra3prio
# banho em local improprio
# bueiro aberto sem tampa
# bueiro entupido
# calaonia
# calote
# calunia
# camera off line
# cameras de videomonitoramento
# charlatanismo
# comarcio ambulante
# comercio ambulante
# concussao
# conduta inconveniente
# constrangimento ilegal
# construaao irregular
# construcao irregular
# contrabando ou descaminho
# corrupaao de menores
# corrupcao ativa
# corrupcao de menores
# corte irregular de arvore
# crianaa perdida desaparecida
# crianca perdida desaparecida
# crime ambiental
# dano
# denaoncia de bomba
# denuncia de bomba
# denuncia improcedente
# depa3sito irregular
# deposito irregular
# desabamento
# desabamento de telhado cobertura
# desacato
# desaparecimento
# descumprimento lei 15799 2021 covid 19
# desinteligaancia
# desinteligencia
# deslizamenton de terra
# desobediaancia
# desobediencia
# destelhamento
# devoluaao de coisa achada
# devolucao de coisa achada
# difamaaao
# difamacao
# discriminaaao
# discriminacao
# disparo de arma
# distaorbio
# embriaguez
# encaminhamento
# envenenamento
# enxurrada
# erosao
# escolta
# escrito ou objeto obsceno panfletos pornograficos
# estelionato
# estupro
# evento
# exploraaao de menores
# exploracao de menores
# explosao
# extorsao
# extravio de documento
# extravio de equipamento
# extravio sonegaaao ou inutilizaaao de livro ou doc
# extravio sonegacao ou inutilizacao de livro ou doc
# falsidade ideola3gica falsa identidade
# falsidade ideologica falsa identidade
# falsificacao de documento publico
# favorecimento da prostituicao
# fingir se funcionario publico
# fiscalizaaaes e orientaaaes
# fiscalizacoes e orientacoes
# fornecimento de bebida alcoa3lica a menores
# fornecimento de bebida alcoolica a menores
# fornecimento de lona
# fuga de aluno interno
# fuga de paciente
# fundada suspeita abordagem
# furto
# homicadio
# homicidio
# homofobia
# impedimento ou perturbaaao de cerima nia funeraria
# impedimento ou perturbacao de cerimonia funeraria
# importunaaao ofensiva ao pudor
# importunaaaoa sexual
# importunacao ofensiva ao pudor
# importunacao sexual
# incaandio
# incendio
# incendio explosao em edificaaao
# incendio explosao em edificacao
# incitacao ao crime
# infiltraaao
# infiltracao
# injaoria
# injuria
# inundaaao enchente
# inundacao enchente
# invasao
# jogo de azar
# lesao corporal
# liberacao de pessoa presa apreendida por recusa no recebimento pela dp
# manifestaaao
# manifestacao
# manipulaaao de explosivo
# material abandonado
# maus tratos a animais
# maus tratos a pessoas
# mendigar por ociosidade ou cupidez
# menor gazeando aula
# menores abordando transeuntes
# moeda falsa
# notificaaao
# obito
# obito defesa civil
# obstruaao da atividade policial
# obstrucao da atividade policial
# obstrucao de via
# ocupaaao irregular
# omissao de socorro
# orgaos acionados
# orientaaao
# orientacao
# paciente usuario alterado
# panfletagem pornografica
# patrulha maria da penha
# peculato
# perseguiaao stalking
# perseguicao stalking
# perturbaaao do sossego
# perturbacao do sossego
# pesca em local proibido
# poda de arvore
# poluiaao visual ambiental
# poluicao visual ambiental
# porte de artefato explosivo
# porte ilegal
# posse sexual mediante fraude
# pragas animais
# prevaricaaao
# prevaricacao
# prostituicao
# proteaao ao patrima nio
# protecao ao patrimonio
# quadrilha ou bando
# queda de aeronave
# queda de arvore
# queda de fios de energia
# queda de galho
# queda de muro
# queda de poste
# queda de revestimento de fachadas
# quedas de objetos ou partes de construaaes
# quedas de objetos ou partes de construcoes
# queima a cau aberto
# queima a ceu aberto
# rachadura em edificaaao
# racismo
# receptaaao
# receptacao
# recolhimento de materiais
# recusar se identificar ao policial
# resistaancia
# resistencia
# retirada de invasao
# risco de acidente a vida
# risco de acidente a vida defesa civil
# risco de desabamento desmoronamento
# risco de explosao
# risco de queda de arvore
# risco de queda de fios de energia
# risco de queda de galho
# risco de queda de poste
# rixa
# rompimento de barragem
# ronda
# roubo
# roubo furto extravio recuperaaao apreensao de armas de fogo
# roubo furto extravio recuperacao apreensao de armas de fogo
# rufianismo
# saturacao
# seducao
# seqa14estro e carcere privado
# sequestro e carcere privado
# situaaao de risco
# situacao de risco
# substancia ilacita
# substancia ilicita
# substancia lacita
# substancia licita
# suicadio
# suicidio
# tentativa
# tentativa de homicadio
# tentativa de suborno
# transito
# trote telefonico
# usar de uniforme ou distintivo de funcao publica que nao exerce
# uso indevido do cartao transporte
# uso indevido do telefone publico
# vadiagem
# vazamento ou derramamento de produto perigoso ou infectante
# veaculo
# veiculo
# venda proibida de produtos especaficos a menores
# venda proibida de produtos especificos a menores
# verificaaao
# verificacao
# vias de fato
# vilipendio a cadaver
# violaaao de medida protetiva lei maria da penha
# violaaao de sepultura taomulo
# violaancia arbitraria
# violacao de medida protetiva lei maria da penha
# violacao de sepultura tumulo
# violencia arbitraria
# vistoria
# voo drone gmc
# voo drone irregular
# zeladoria urbana

# %% [markdown]
# Assim como com a coluna de bairros, também há erros de digitração e casos similares nas colunas de natureza das ocorrências. Por exemplo:
#
# - `ameaaa` (deveria ser `ameaca`)
# - `perseguiaao` (deveria ser `perseguicao`)
#
# Além da correção desses erros, criaremos features que classifiquem o tipo de ocorrência registrada. Serão features boolenadas, indicando se a ocorrência se relacionada a cada uma das seguintes categoraias:
#
# - Crime violento;
# - Crime não violento;
# - Acidente de trânsito;
# - Acidente natural;
# - Crime patrimonial;
# - Crime de administração pública;
# - Crime quanto a honra e discriminação;
# - Crime criança adolescente;
# - Crime fraude documental;
# - Crime drogas e substancias licitas e ilicitas;
# - Crime ordem publica;
# - Risco estrutural;
# - Explosivos e produtos perigosos;
# - Pessoas desaparecidas;
# - Materiais e objetos;
#
# O objetivo dessas features é transformar os dados textuais em dados estruturados, facilitando análises quantitativas e estatísticas.

# %% [markdown]
# ## . Pipeline de limpeza de dados
#
# Iremos executar um pipeline inicial de limpeza de dados executando as funções que construímos acima:
#
# - `limpar_texto`;
# - `mapear_binario`;
# - `mapear_dia_semana`
# - `tratar_coluna_hora`
# - `adicionar_periodo_dia`
#
# e realizar drop de colunas que não serão necessárias.

# %%
def executar_pipeline(arquivo):
    df = pd.read_csv(arquivo, sep=";", encoding="latin1", dtype=str)

    for col in COLUNAS_TEXTO:
        if col in df.columns:
            df[col] = df[col].apply(limpar_texto)
    
    if COLUNA_BAIRRO_NOME in df.columns:
        df[COLUNA_BAIRRO_NOME] = df[COLUNA_BAIRRO_NOME].apply(padronizar_bairro)
        
    for col in COLUNAS_BINARIAS:
        if col in df.columns:
            df[col] = df[col].apply(mapear_binario).astype("Int64")

    for col in COLUNA_DIA_SEMANA:
        if col in df.columns:
            df[col] = df[col].apply(mapear_dia_semana).astype("Int64")

    df = tratar_coluna_hora(df, COLUNA_HORA)
    df = adicionar_periodo_dia(df, f"{COLUNA_HORA}_HORA")

    colunas_para_remover = [col for col in DEFAULT_DROP_COLUMNS if col in df.columns]
    if colunas_para_remover:
        df = df.drop(columns=colunas_para_remover)
    
    caminho_saida = output_dir / arquivo.name 
    df.to_csv(caminho_saida, sep=";", index=False, encoding="utf-8")

    return df

# %%
df_limpo = executar_pipeline(arquivo)
