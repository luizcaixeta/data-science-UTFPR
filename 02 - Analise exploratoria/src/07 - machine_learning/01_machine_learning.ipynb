# %%
import sys 
import os 

sys.path.append(os.path.join('..', '..'))

# %%
from pathlib import Path
import pandas as pd
import numpy as np

# %%
data_dir = Path("../../data/base_de_dados_final/")
arquivo = data_dir / "base_feature_engineering.csv"

# %%
df = pd.read_csv(arquivo, sep=";", encoding="latin1", dtype=str)

# %%
df.head()
# Out:
#   ATENDIMENTO_BAIRRO_NOME FLAG_EQUIPAMENTO_URBANO FLAG_FLAGRANTE  \
# 0       cidade industrial                       0              0
# 1              fazendinha                       1              0
# 2                 uberaba                       0              0
# 3           sitio cercado                       0              0
# 4               tatuquara                       1              0
#
#   NATUREZA1_DEFESA_CIVIL NATUREZA2_DEFESA_CIVIL NATUREZA3_DEFESA_CIVIL  \
# 0                      0                      0                      0
# 1                      0                      0                      0
# 2                      0                      0                      0
# 3                      0                      0                      0
# 4                      0                      0                      0
#
#   NATUREZA4_DEFESA_CIVIL NATUREZA5_DEFESA_CIVIL OCORRENCIA_DIA_SEMANA  \
# 0                      0                      0                     5
# 1                      0                      0                     5
# 2                      0                      0                     5
# 3                      0                      0                     5
# 4                      0                      0                     5
#
#   OCORRENCIA_MES  ... OUTROS      log_rendimento             log_pop  \
# 0              1  ...      1  1.2725655957915476  12.054569291774312
# 1              1  ...      1  1.4445632692438664  10.249025712063943
# 2              1  ...      1  1.5933085305042167  11.181751169442313
# 3              1  ...      1  1.2412685890696329  11.664899491892095
# 4              1  ...      1  1.1085626195212777  10.856862100640145
#
#   rendimento_medio_responsavel_sm_estimado_norm  \
# 0                           0.10837118754055809
# 1                           0.15184944841012332
# 2                           0.19597663854639846
# 3                           0.10123296560674888
# 4                           0.07332900713822194
#
#   pct_alfabetizacao_15mais_estimado_norm  \
# 0                     0.5860284605433375
# 1                      0.693402328589909
# 2                      0.693402328589909
# 3                     0.5795601552393275
# 4                     0.3984476067270371
#
#   pct_sem_banheiro_sanitario_estimado_norm  \
# 0                       0.8524590163934427
# 1                       0.9344262295081966
# 2                        0.819672131147541
# 3                       0.8360655737704918
# 4                        0.721311475409836
#
#   pct_esgotamento_precario_estimado_norm  \
# 0                     0.9581193838254172
# 1                     0.9813863928112966
# 2                     0.9050064184852374
# 3                     0.9849165596919127
# 4                     0.8515725288831836
#
#   pct_sem_rede_geral_agua_estimado_norm  \
# 0                    0.9939548202354438
# 1                    0.9977728285077951
# 2                     0.960229080496341
# 3                    0.9910913140311803
# 4                    0.9882278078269169
#
#   pct_lixo_destino_inadequado_estimado_norm           IQV_final
# 0                        0.9838709677419355   54.71668983776517
# 1                        0.9919354838709677  60.721067022486544
# 2                        0.9838709677419355   60.21912055346904
# 3                         0.995967741935484   54.42678060677812
# 4                        0.9193548387096774  44.729775885755416
#
# [5 rows x 33 columns]
